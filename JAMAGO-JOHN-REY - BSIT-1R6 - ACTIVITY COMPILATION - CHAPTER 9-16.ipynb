# %%
#i. Learning about Chapter 9 (Wordcount: 209)
print('''
#i. Learning about Chapter 9 (Wordcount: 209)

The video talks about the data structure names Graph. The data structure graph
is actually a non linear. It consist of nodes and edges. Nodes are also label 
as set of vertices while edges connect connects every pair of nodes. It was 
stated in the video of “codebasic” that graph data structure solve many real
life problem.   He stated that most flight bookings and Facebook friend 
suggestion might have used graph as data structure.In Facebook friends, there
are nodes that connect to each other. Individual entities are called nodes and
the thing that connects those nodes are called edges. He stated in the video 
that Facebook friend suggestion is a graph data structure.   In his video he 
uses flight path as an example. Another example are flight routes between two
or more cities. And it is a directive graph because there is a direction. The
difference between graph and a tree is that there are only one path between two 
nodes . The problem is what is the shortest path from this certain country  to
another country. He also emphasize that whenever you are writing recursive function,
you need to think about the simplest case. In conclusion, graph data structure is
very important in our daily lives. 

''')
# Out:
# #i. Learning about Chapter 9 (Wordcount: 209)
#
# The video talks about the data structure names Graph. The data structure graph
# is actually a non linear. It consist of nodes and edges. Nodes are also label
# as set of vertices while edges connect connects every pair of nodes. It was
# stated in the video of “codebasic” that graph data structure solve many real
# life problem.   He stated that most flight bookings and Facebook friend
# suggestion might have used graph as data structure.In Facebook friends, there
# are nodes that connect to each other. Individual entities are called nodes and
# the thing that connects those nodes are called edges. He stated in the video
# that Facebook friend suggestion is a graph data structure.   In his video he
# uses flight path as an example. Another example are flight routes between two
# or more cities. And it is a directive graph because there is a direction. The
# ...

# %%
#i. Learning about Chapter 10 (Wordcount:232)
print('''

Learning about Chapter 10 (Wordcount:232)

The video talks about binary search. It is a popular search algorithm that 
can find element using log(n) time complexity. Binary search is a search 
that sort an array repeatedly by dividing search interval by half. He gave 
a set of array as an example namely 4, 9, 11, 17, 21, 25, 29, 32 and 38. In
linear search, there are 7 iteration until you find the number 32. But there
are much better method and that is binary search. First, you take the number
21, then compare it with 32 and of course it is less than 32. Now by doing 
this comparison, you have ruled out the possibility that the number exist in
the left hand side of the array.   In the first comparison, you discarded 
half of the elements. Next, you go to the middle of the remaining arrays. The 
middle is whether 29 or 32 but he just go with 29. Then after that, you
compare, and discard the left hand side of the array. And that left hand is 25
and 29. Now, you are left with only two elements. And that elements is 32 and 
38. The same process, you take the middle element of the remaining arrays. And
now you found 32 with only 3 iteration unlike the linear search which is 7 
iteration. In binary search, you are diving your search space by half. 
''')
# Out:
# Learning about Chapter 10 (Wordcount:232)
#
# The video talks about binary search. It is a popular search algorithm that
# can find element using log(n) time complexity. Binary search is a search
# that sort an array repeatedly by dividing search interval by half. He gave
# a set of array as an example namely 4, 9, 11, 17, 21, 25, 29, 32 and 38. In
# linear search, there are 7 iteration until you find the number 32. But there
# are much better method and that is binary search. First, you take the number
# 21, then compare it with 32 and of course it is less than 32. Now by doing
# this comparison, you have ruled out the possibility that the number exist in
# the left hand side of the array.   In the first comparison, you discarded
# half of the elements. Next, you go to the middle of the remaining arrays. The
# middle is whether 29 or 32 but he just go with 29. Then after that, you
# compare, and discard the left hand side of the array. And that left hand is 25
# ...

# %%
#i. Learning about Chapter 11(Wordcount:219)
print('''
#i. Learning about Chapter 11 (Wordcount:219)

The video talks about bubble sort. Bubble sort is the simplest sorting array and algorithm. 
So, how does it works? It works by repeatedly swapping the adjacent elements if they are in 
the wrong order. This technique is covered as the most common technique in performing a
sorting. It may not be the most efficient but it is probably the most easy and simple 
technique to understand. It can be applied in many things like transaction. Imagine, you 
want to sort a transaction by the amount or price so you will know who bought the most 
expensive item in the shop. Or maybe you want to sort it by name or however you may like. 
When you are doing software development, bubble sort is one of the sorting techniques. It 
works by comparing the first two numbers with each other. If they are in the correct order
then do not touch anything. You just have to repeat the process again and again for each 
number until they are in the correct position. It is called bubble sort because just like 
bubble, it will go from bottom to top. The space complexity of bubble sort is just the
order of 1 because we are not using any additional space. We are just using the same array
and we are swapping.

''')

# %%
#i. Learning about Chapter 12(Wordcount:207)
print('''
Learning about Chapter 12(Wordcount:207)

The video talks about quick sort. Quick sort is a popular sorting algorithm. This technique 
uses divide and conquer approach to divide given list into partitions and then recursively
sort these partitions. So how does it start?. It start with a pivot element and tries to
put pivot element in its correct position. He presented and goes over with two theories. 
These two popular partition schemes are called hoare partition and lomuto partition. 
Quick sort is a divide and conquer  algorithm. It first picks an element as a pivot and
partitions the given array around the picked pivot. You should pick the first element
as a pivot. Quick sort is very important and useful for sorting arrays. Lomuto’s 
partition scheme is much easier to implemenet than the Hoare scheme. Hoare’s Partition
Scheme works by initializing two indexes that start at two ends, the two indexes move 
toward each other until an inversion is found. Two values are swapped and the process is
repeated when inversion is found. Hoare’s scheme is more efficient that Lomuto’s scheme.
Hoare’s scheme does three times fewer swaps on average, and it creates efficient partitions
even when all elements and values are equal.
''')

# %%
#i. Learning about Chapter 13(Wordcount:227)
print('''
Learning about Chapter 13(Wordcount:227)

The video talks about insertion sort. Insertion sort is a simple sorting algorithm that
is best for small list according to him. Insertion sort algorithm also have very few 
lines of code. If your array has many elements or if your array is too big then insertion 
sort might not be the perfect choice as it performs in 0(n^2) time complexity. The speaker
also challenged its viewers to think of a way that will sort the array without creating 
another array. If you have answered his question, then you will make a good programming
since problem solving skill is important in programming specifically in algorithm The 
insertion sort algorithm works similar to how you sort playing cars in your hand. He 
mentioned that there is a way to use insertion sort without using different array. It 
works by comparing the first element to its right element. Any element beyond the 
imaginary pointer you made should be sorted. Always compare the element to its 
predecessor. If the element is smaller than its predecessor. Then compare it to the
previous one. Move the greater elements to one position up to make space for the
swapped element. Just keep on repeating the process until everything is perfectly 
sorted. Simple implementation, efficient, adaptive, stable, In place, and online are 
the advantages of insertion sort algorithm that was mentioned in the video. 

''')

# %%
#i. Learning about Chapter 14(Wordcount:213)
print('''
Learning about Chapter 14(Wordcount:213)

The video talks about merge sort . Merge sort is a sorting algorithm that gives 
time complexity of 0 (n logn). It performs better than insertion sort, bubble sort
and etc. Merge sort according to the video is a divide and Conquer algorithm. It 
first divides the array into halves.You now have 2 sets of array after dividing 
them. After that, You still have to divide them again. And now you have 4 sets 
of array with two elements. After dividing, you also have to divide them until
all elements are alone in their arrays. After that, you merge the two array 
sorted. And now you are back with 4 sets of array. After that, Merge again. 
Now you have two sets of array. And then Merge again and now you have one 
sorted array. It is very easy. Imagine two sorted array. Create an imaginary 
pointer at the first element of each array. Compare them who’s greater and 
who’s lesser. And always drop down the element with lesser value. If you keep
doing it, you will end up with one perfectly sorted array. According to him,
It is much easier to sort two already sorted array since yo just have to keep 
looking at the pointer you created.
''')

# %%
#i. Learning about Chapter 15(Wordcount:229)

print('''
#i. Learning about Chapter 15(Wordcount:229)

The video talks about Shell sort. He suggested that we should first watch the
insertion sort that was previously discussed by him. Shell sort is a variation 
of insertion. So first, how does insertion sort works ? It works by by comparing
the first element to its right element. Any element beyond the imaginary pointer
you made should be sorted. Always compare the element to its predecessor. If the
element is smaller than its predecessor. Then compare it to the previous one. 
Move the greater elements to one position up to make space for the swapped 
element. Just keep on repeating the process until everything is perfectly sorted.
Shell sort works by creating n gaps. The number of gaps according to him depend
on you as long as it will always end at the gap of 1.  If you are using 3 gaps
then arrange the highlighted element in the array. After the highlighted array 
sorted then you should reduce the gap and repeat the same process. Arrange the 
elements in the array with the gap of two. After arranging, then you are now at
the gap of 1 . So basically, according to the video, gap of 1 is literally an 
insertion sort. You just have to use insertion sort but it is more easier because 
most of the elements are already sorted because of the previous process
''')

# %%
#i. Learning about Chapter 16(Wordcount:202)
print('''
#i. Learning about Chapter 16(Wordcount:202)

The video talks about selection sort. Selection sort is a a simple algorithm for 
sorting. It gives 0(n^2) BIG 0 complexity. Selection sort woks by finding a candidate
for the first position. And the candidate for the first position is the minimum number
in the list. So, you look at the first element and look for the minimum number. After
finding the minimum number, you swap them with the first element.  So now, the first
element is already sorted. The sub array you created should be sorted perfectly and 
the remaining array should be or assumed to be unsorted. Now you have to move on to 
the second element. You have to find the candidate for the second position. And the
element for that position is the second minimum element/ number or rather it is a
minimum element in the unsorted array. The left hand or the first two element is 
already sorted. If you keep repeating this process, all of the elements in the list
will be sorted. Doing this program is not very efficient but in certain cases it 
could be useful. It could be useful especially if you have an extra space and this
is a very simple techniques. 
''')

# %%
#i. Learning about Chapter 17(Wordcount:270)
print(''' 
#i. Learning about Chapter 17(Wordcount:270)

The video talks about recursion such that even high school student can understand since
it is very simple. Recursion is a very important concept in the field of computer science.
Any problem can be divided into further small and simpler problem. He uses people waiting
outside pizza store as an example. The people are waiting for their pizza delivery. The 
owner of the store Roberto realizes that people are getting bored standing in queue. So,
he offers a garlic bread each as a compliment. The first person in queue gets 1 garlic 
bread, the second person get 2 garlic bread and so on. Roberto is thinking that maybe 
the last person standing would be more bored so he gave them reward. But still there 
is a delay. So Roberto offers more discount by letting them have an activity which 
will let them enjoy and avoid  boredom. The person in queue needs to count the number
of breads that re in front of them including their own breads. Everybody are counting 
whats in front of them which is a very long and kind of complicated process. The last 
person decided to ask the person in front of her the number of breads in front of her. 
Then he added them to her own breads. The everybody follows. You are basically doing three
steps in this approach. First step, you divide the bigger problem into smaller and simpler
problem. In recursion, you need to have that base condition and the third point here is
once you have the answer with base condition you roll back that answer way up in the chain.
''')

# %%
#ii. 1. Implement the simple methods get_num and get_den that will return the numerator and denominator of a fraction.

class Fraction:

    def __init__(self, nume, deno):

        self.num = nume     # the numerator 
        self.den = deno     # the denominator

    def __str__(self):
        return str(self.num) + "/" + str(self.den)

    def getNum(self):
        return self.num

    def getDen(self):
        return self.den

TheFraction = Fraction(1, 3)
print(TheFraction)

print(('The Numerator is '), TheFraction.getNum())
print(('The Denominator is'), TheFraction.getDen())
# Out:
# 1/3
# The Numerator is  1
# The Denominator is 3

# %%
#ii. 2. Research the __radd__ method. How does it differ from __add__? When is it used? Implement __radd__
print('''
2. Research the __radd__ method. How does it differ from __add__? When is it used? Implement __radd__

a.  The __radd__ methods are called to implement the binary arithmetic operations (+, -, *, /, //, %, 
    divmod(), pow(), **, <<, >>, &, , |) with reflected (swapped) operands. 
    
b.  The __radd__ methods are only called if the left operand does not support the corresponding operation 
    while the __add__ method add two instances of a custom object.
    
c.  These functions are only called if the left operand does not support the corresponding operation and 
    the operands are of different types. [2] For instance, to evaluate the expression x - y, where y is 
    an instance of a class that has an rsub() method, y.rsub(x) is called if x.sub(y) returns NotImplemented.

''')
class X:
    
    def __init__(self, num):
        self.num = num

    def __str__(self):
        return str(self.num)

    def __add__(self, other):
        return self.num + other.num
    
    __radd__ = __add__


class Y:

    def __init__(self, num):
        self.num = num

    def __str__(self):
        return str(self.num)


x = X(50)
y = Y(200)

print(x+y)

print(y+x)
# Out:
# 2. Research the __radd__ method. How does it differ from __add__? When is it used? Implement __radd__
#
# a.  The __radd__ methods are called to implement the binary arithmetic operations (+, -, *, /, //, %,
#     divmod(), pow(), **, <<, >>, &, , |) with reflected (swapped) operands.
#
# b.  The __radd__ methods are only called if the left operand does not support the corresponding operation
#     while the __add__ method add two instances of a custom object.
#
# c.  These functions are only called if the left operand does not support the corresponding operation and
#     the operands are of different types. [2] For instance, to evaluate the expression x - y, where y is
#     an instance of a class that has an rsub() method, y.rsub(x) is called if x.sub(y) returns NotImplemented.
#
#
# 250
# 250

# %%
#ii. 3. Research the __repr__ method. How does it differ from __str__? When is it used? Implement __repr__.
print('''
3.  Research the __repr__ method. How does it differ from __str__? When is it used? Implement __repr__.

a.  __repr__(self): Called by the repr() built-in function and by string conversions (reverse quotes) 
    to compute the “official” string representation of an object. If at all possible, this should look 
    like a valid Python expression that could be used to recreate an object with the same value (given 
    an appropriate environment). If this is not possible, a string of the form <...some useful 
    description...> should be returned. The return value must be a string object. If a class defines
    __repr__() but not __str__(), then __repr__() is also used when an “informal” string representation 
    of instances of that class is required. This is typically used for debugging, so it is important that 
    the representation is information-rich and unambiguous.

b.  object.__str__(self): Called by the str() built-in function and by the print statement to compute 
    the “informal” string representation of an object. This differs from repr() in that it does not have 
    to be a valid Python expression: a more convenient or concise representation may be used instead. The 
    return value must be a string object.
c.  If a class defines
    __repr__() but not __str__(), then __repr__() is also used when an “informal” string representation 
    of instances of that class is required. This is typically used for debugging, so it is important that 
    the representation is information-rich and unambiguous. __repr__ is used to compute the “official”
    string representation of an object and is typically used for debugging.

''')
class Student:
    def __init__(self, name, section):
        self.name = name
        self.section = section

    def __repr__(self):
        rep = 'Student(' + self.name + ',' + str(self.section) + ')'
        return rep


# Let's make a Person object and print the results of repr()

student = Student("John-Rey Jamago", 6)
print(repr(student))
# Out:
# 3.  Research the __repr__ method. How does it differ from __str__? When is it used? Implement __repr__.
#
# a.  __repr__(self): Called by the repr() built-in function and by string conversions (reverse quotes)
#     to compute the “official” string representation of an object. If at all possible, this should look
#     like a valid Python expression that could be used to recreate an object with the same value (given
#     an appropriate environment). If this is not possible, a string of the form <...some useful
#     description...> should be returned. The return value must be a string object. If a class defines
#     __repr__() but not __str__(), then __repr__() is also used when an “informal” string representation
#     of instances of that class is required. This is typically used for debugging, so it is important that
#     the representation is information-rich and unambiguous.
#
# ...

# %%
#ii. 4. The most simple arithmetic circuit is known as the half adder. Research the simple half-adder circuit. Implement this circuit.
print('''
4. The most simple arithmetic circuit is known as the half adder. Research the simple half-adder circuit. Implement this circuit.

a.  A half adder is a type of adder, an electronic circuit that performs the addition of numbers. The half adder is able to add
    two single binary digits and provide the output plus a carrying value. It has two inputs, called A and B, and two outputs S 
    (sum) and C (carry).

b. Implementation
''')
# Function
def getResult(Num1, Num2):
    Sum = Num1 ^ Num2
    Carry = Num1 & Num2
      
    # printing
    print("Sum (XOR)  =", Sum)
    print("Carry (AND)=", Carry)
Num1 = 1
Num2 = 1
getResult(Num1, Num2)
# Out:
# 4. The most simple arithmetic circuit is known as the half adder. Research the simple half-adder circuit. Implement this circuit.
#
# a.  A half adder is a type of adder, an electronic circuit that performs the addition of numbers. The half adder is able to add
#     two single binary digits and provide the output plus a carrying value. It has two inputs, called A and B, and two outputs S
#     (sum) and C (carry).
#
# b. Implementation
#
# Sum (XOR)  = 0
# Carry (AND)= 1

# %%
#ii. 5. Design a class to represent a playing card and another one to represent a deck of cards. Using these two classes, implement
#       your favorite card game.
print('''
5.  Design a class to represent a playing card and another one to represent a deck of cards. Using these two classes, implement your
    favorite card game.
''')
import random
class Card:
    def __init__(self, suit, val):
        self.suit = suit
        self.value = val
    
    def show(self):
        print("{} of {}".format(self.value, self.suit))
class Deck:
    def __init__(self):
        self.cards = []
        self.build()
    def build(self):
        for s in ["Clubs", "Spades", "Diamonds", "Hearts"]:
            for v in range(1, 14):
                self.cards.append(Card(s, v))
    def show(self):
        for c in self.cards:
            c.show()
    def shuffle(self):
        for i in range(len(self.cards) -1, 0, -1):
            r = random.randint(0, i)
            self.cards[i], self.cards[r] = self.cards[r], self.cards[i]
    def draw(self, deck):
        self.hand.append(deck.drawCard())
        return self
    def drawCard(self):
        return self.cards.pop()
class Player:
    def __init__(self, name):
        self.name = name
        self.hand = []
    def draw(self, deck):
        return self
    def showHand(self):
        for card in self.hand:
            card.show()
deck = Deck()
deck.shuffle()
#deck.show()
card = deck.drawCard()
card.show()

johnrey = Player("John-Rey")
johnrey.draw(deck)
johnrey.showHand()
    
#card = Card("Card", 6)
#card.show()
# Out:
# 5.  Design a class to represent a playing card and another one to represent a deck of cards. Using these two classes, implement your
#     favorite card game.
#
# 12 of Spades

# %%
#ii. 6. Design and implement an experiment to do benchmark comparisons of the two queue(enqueue,dequeue) implementations. What can 
#       you learn from such an experiment?
print('''
6.  Design and implement an experiment to do benchmark comparisons of the two queue(enqueue,dequeue) implementations. What can you 
    learn from such an experiment?
''')
# Queue implementation in Python(Enqueue and dequeue comparison)

class Queues:
    def __init__(self):
        self.queue = []
    def enqueue(self, item):
        self.queue.append(item)
    def dequeue(self):
        if len(self.queue) < 1:
            return None
        return self.queue.pop(0)
    def display(self):
        print(self.queue)
    def size(self):
        return len(self.queue)
print("     Current Elements(Enqueue Implemented)")
qli = Queues()
qli.enqueue(1)
qli.enqueue(2)
qli.enqueue(3)
qli.enqueue(4)
qli.enqueue(5)
qli.display()
print("     Enqueue implemented(again):")
qli.enqueue(6)
qli.display()
print("     Dequeue implemented")
qli.dequeue()
qli.display()
print("     Enqueue implemented(again):")
qli.enqueue(7)
qli.enqueue(8)
qli.display()
print('     I learned that both queue and dequeue are both useful and we might be sing it in some programns unknowingly.')
# Out:
# 6.  Design and implement an experiment to do benchmark comparisons of the two queue(enqueue,dequeue) implementations. What can you
#     learn from such an experiment?
#
#      Current Elements(Enqueue Implemented)
# [1, 2, 3, 4, 5]
#      Enqueue implemented(again):
# [1, 2, 3, 4, 5, 6]
#      Dequeue implemented
# [2, 3, 4, 5, 6]
#      Enqueue implemented(again):
# [2, 3, 4, 5, 6, 7, 8]
#      I learned that both queue and dequeue are both useful and we might be sing it in some programns unknowingly.

# %%
#ii. 7. Consider a real life situation. Formulate a question and then design a simulation that can help to answer it. Possible situations include:
print('''
7. Consider a real life situation. Formulate a question and then design a simulation that can help to answer it. Possible situations include:
    a. Cars lined up at a car wash
    b. Customers at a grocery store check-out
    c. Airplanes taking off and landing on a runway
    d. A bank teller
        Be sure to state any assumptions that you make and provide any probabilistic data that must be considered as part of the scenario.
        No more coding for this item, just explanation.
        
    a.  What is the efficient way to make the cars more faster?
            By applying the first in and first out, this can be organize immedietly. No breaking of line will make a huge difference. 
            Calculating the time taken before car washing fishes will also help you comopute your average profit per car or per hour a day.
        
    b. What is the most efficient way to make the line clean and faster?
            The same with the first one, by applying the first in and first out method. Breakng of lines will be prohibited. 
            Dividing cashier into different section like one basket, one cart, cash only and etc. will also help ease up the 
            line if the grocery line is long.
    
    c. What is the efficient way to schedule/arrange the taking off and landing of the airplanes
            Calculating the exact time taken is the most importatnt. Plane must wait for their turn to land. 
            Constant communication will also help.
    
    d. What is the most efficient way to make the bank teller line faster, cleaner and more well ordered.
            The common way is already good. Giving or assigning numbers every person and  an automative program 
            will display a number on the screen to let them know when is their turn and what teller number they should go.
''')
# Out:
# 7. Consider a real life situation. Formulate a question and then design a simulation that can help to answer it. Possible situations include:
#     a. Cars lined up at a car wash
#     b. Customers at a grocery store check-out
#     c. Airplanes taking off and landing on a runway
#     d. A bank teller
#         Be sure to state any assumptions that you make and provide any probabilistic data that must be considered as part of the scenario.
#         No more coding for this item, just explanation.
#
#     a.  What is the efficient way to make the cars more faster?
#             By applying the first in and first out, this can be organize immedietly. No breaking of line will make a huge difference.
#             Calculating the time taken before car washing fishes will also help you comopute your average profit per car or per hour a day.
#
#     b. What is the most efficient way to make the line clean and faster?
# ...

# %%
#ii. 8. Implement a queue using linked lists.
print('''
8. Implement a queue using linked lists.
''')
class Node:
      
    def __init__(self, data):
        self.data = data
        self.next = None
class Queue:
      
    def __init__(self):
        self.front = self.rear = None
  
    def isEmpty(self):
        return self.front == None
      

    def EnQueue(self, item):
        temp = Node(item)
          
        if self.rear == None:
            self.front = self.rear = temp
            return
        self.rear.next = temp
        self.rear = temp
  
    def DeQueue(self):
          
        if self.isEmpty():
            return
        temp = self.front
        self.front = temp.next
  
        if(self.front == None):
            self.rear = None
            
if __name__== '__main__':
    qli = Queue()
    qli.EnQueue(1)
    qli.EnQueue(2)
    qli.DeQueue()
    qli.EnQueue(3)
    qli.EnQueue(4)
    qli.DeQueue()   
    print("Queue Front " + str(qli.front.data))
    print("Queue Rear " + str(qli.rear.data))
# Out:
# 8. Implement a queue using linked lists.
#
# Queue Front 3
# Queue Rear 4

# %%
#ii. 9. Write a recursive function to compute the factorial of a number.
print('9. Write a recursive function to compute the factorial of a number.')

def recurtion_factorial(j):
   if j == 1:
       return j
   else:
       return j*recurtion_factorial(j-1)

num = 0

if num < 0:
   print("Error, negative number was inputted")
elif num == 0:
   print("The factorial of 0 is 1")
else:
   print("The factorial of", num, "is", recurtion_factorial(num))

# %%
#ii. 10. Set up a random experiment to test the difference between a sequential search and a binary search on a list of integers.
print('''
10. Set up a random experiment to test the difference between a sequential search and a binary search on a list of integers.
''')
def Sequential_Search(dlist, item):

    pos = 0
    found = False
    
    while pos < len(dlist) and not found:
        if dlist[pos] == item:
            found = True
        else:
            pos = pos + 1
    
    return found, pos
print('     Sequential Search')
print(Sequential_Search([1,2,3,5,8], 6))
print(Sequential_Search([1, 2, 3, 4],1))

def binary_search(item_list,item):
    first = 0
    last = len(item_list)-1
    found = False
    while( first<=last and not found):
        mid = (first + last)//2
        if item_list[mid] == item :
            found = True
        else:
            if item < item_list[mid]:
                last = mid - 1
            else:
                first = mid + 1	
    return found
print('      Binary Search')
print(binary_search([1,2,3,5,8], 6))
print(binary_search([1, 2, 3, 4],1))
print('''
    In sequential search, the algorithm is iterative in nature while in the binary search uses divide and conquer techniques.
    Also, the code is sequential search is lesser than binary since binay search is a little complex.
''')
# Out:
# 10. Set up a random experiment to test the difference between a sequential search and a binary search on a list of integers.
#
#      Sequential Search
# (False, 5)
# (True, 0)
#       Binary Search
# False
# True
#
#     In sequential search, the algorithm is iterative in nature while in the binary search uses divide and conquer techniques.
#     Also, the code is sequential search is lesser than binary since binay search is a little complex.

# %%
#ii. 11. Suppose you are a computer scientist/art thief who has broken into a major art gallery. All you have with you to haul out your stolen art is your knapsack which only holds W pounds of art, but for every piece of art you know its value and its weight. Write a dynamic programming function to help you maximize your profit. Here is a sample problem for you to use to get started: Suppose your knapsack can hold a total weight of 20. You have 5 items as follows:
print('''
11. Suppose you are a computer scientist/art thief who has broken into a major art gallery. All you have with you to haul out your stolen art 
    is your knapsack which only holds W pounds of art, but for every piece of art you know its value and its weight. Write a dynamic programming 
    function to help you maximize your profit. Here is a sample problem for you to use to get started: Suppose your knapsack can hold a total 
    weight of 20. You have 5 items as follows:
''')
val = [3, 4, 8, 8, 10 ]
wt = [2, 3, 4, 5, 9 ]
W = 20
n = len(val)
 
t = [[-1 for i in range(W + 1)] for j in range(n + 1)]
 

def knapsack(wt, val, W, n):

    if n == 0 or W == 0:
        return 0
    if t[n][W] != -1:
        return t[n][W]
 
    if wt[n-1] <= W:
        t[n][W] = max(
            val[n-1] + knapsack(
                wt, val, W-wt[n-1], n-1),
            knapsack(wt, val, W, n-1))
        return t[n][W]
    elif wt[n-1] > W:
        t[n][W] = knapsack(wt, val, W, n-1)
        return t[n][W]
 
 
print(knapsack(wt, val, W, n))
# Out:
# 11. Suppose you are a computer scientist/art thief who has broken into a major art gallery. All you have with you to haul out your stolen art
#     is your knapsack which only holds W pounds of art, but for every piece of art you know its value and its weight. Write a dynamic programming
#     function to help you maximize your profit. Here is a sample problem for you to use to get started: Suppose your knapsack can hold a total
#     weight of 20. You have 5 items as follows:
#
# 29
